# %%
import json
import joblib
from pprint import pprint
from pathlib import Path

import pandas as pd
import numpy as np

from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

from imblearn.under_sampling import RandomUnderSampler

import xgboost as xgb
from xgboost.callback import EarlyStopping

from isic_helper import DotDict
from isic_helper import compute_auc, compute_pauc
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt

# %matplotlib inline
pd.options.display.max_columns = 1000

# %%
cfg = DotDict()
cfg.seed = 2022

cfg.models_output_dir = "models"
cfg.model_name = "xgb_v2"
cfg.fold_column = "gkf_fold"

cfg.sampling_ratio = 0.01

# %%
id_column = "isic_id"
target_column = "tbp_lv_dnn_lesion_confidence"
group_column = "patient_id"

ord_categorical_features = [
    "sex",
    "tbp_lv_location",
    "tbp_tile_type",
    "tbp_lv_location_simple",
]

ohe_categorical_features = [
    "anatom_site_general", 
    "attribution",
]

attribution_mapper = {
    "Memorial Sloan Kettering Cancer Center": "MSKCC",
    "ACEMID MIA": "ACEMIDMIA",
    "Department of Dermatology, Hospital Clínic de Barcelona": "DoD_HCB",
    "University Hospital of Basel": "UHB",
    "Frazer Institute, The University of Queensland, Dermatology Research Centre": "FI_TUQ-DRC",
    "Department of Dermatology, University of Athens, Andreas Syggros Hospital of Skin and Venereal Diseases, Alexander Stratigos, Konstantinos Liopyris": "DoD_UA",
    "ViDIR Group, Department of Dermatology, Medical University of Vienna": "ViDIR"
}

def boosting_norm_feature(df, value_col, group_cols, err=1e-5):
    stats = ["mean", "std"]
    tmp = df.groupby(group_cols)[value_col].agg(stats)
    tmp.columns = [f"{value_col}_{stat}" for stat in stats]
    tmp.reset_index(inplace=True)
    df = df.merge(tmp, on=group_cols, how="left")
    feature_name = f"{value_col}_patient_norm"
    df[feature_name] = ((df[value_col] - df[f"{value_col}_mean"]) / 
                                       (df[f"{value_col}_std"] + err))
    return df, feature_name

def boosting_minmax_feature(df, value_col, group_cols, err=1e-5):
    stats = ["min", "max"]
    tmp = df.groupby(group_cols)[value_col].agg(stats)
    tmp.columns = [f"{value_col}_{stat}" for stat in stats]
    tmp.reset_index(inplace=True)
    df = df.merge(tmp, on=group_cols, how="left")
    feature_name = f"{value_col}_patient_minmax"
    df[feature_name] = ((df[value_col] - df[f"{value_col}_min"]) / 
                                       (df[f"{value_col}_max"] - df[f"{value_col}_min"] + err))
    return df, feature_name

def boosting_feature_engineering(df, err=1e-5):
    df["sex"] = df["sex"].fillna("missing_sex")
    df["anatom_site_general"] = df["anatom_site_general"].fillna("missing_anatom_site_general")
    df["tbp_tile_type"] = df["tbp_tile_type"].map({"3D: white": "white", "3D: XP": "XP"})
    df["attribution"] = df["attribution"].map(attribution_mapper)

    cols_to_norm = [
        "age_approx",
        "clin_size_long_diam_mm",
        "tbp_lv_A", "tbp_lv_Aext",
        "tbp_lv_B", "tbp_lv_Bext",
        "tbp_lv_C", "tbp_lv_Cext",
        "tbp_lv_H", "tbp_lv_Hext",
        "tbp_lv_L", "tbp_lv_Lext",
        "tbp_lv_areaMM2", "tbp_lv_area_perim_ratio",
        "tbp_lv_color_std_mean",
        "tbp_lv_deltaA", "tbp_lv_deltaB", "tbp_lv_deltaL", "tbp_lv_deltaLB", "tbp_lv_deltaLBnorm",
        "tbp_lv_eccentricity",
        "tbp_lv_minorAxisMM", "tbp_lv_nevi_confidence", "tbp_lv_norm_border",
        "tbp_lv_norm_color", "tbp_lv_perimeterMM",
        "tbp_lv_radial_color_std_max", "tbp_lv_stdL", "tbp_lv_stdLExt",
        "tbp_lv_symm_2axis", "tbp_lv_symm_2axis_angle",
        "tbp_lv_x", "tbp_lv_y", "tbp_lv_z"
    ]
    numerical_features = cols_to_norm[:]
    for col in cols_to_norm:
        df, feature_name = boosting_norm_feature(df, col, ["patient_id"])
        numerical_features += [feature_name]
    
    df["tbp_lv_H_diff"] = df["tbp_lv_H"] - df["tbp_lv_Hext"]
    numerical_features += ["tbp_lv_H_diff"]

    df["tbp_lv_A_diff"] =  df["tbp_lv_Aext"] - df["tbp_lv_A"]
    df, feature_name = boosting_norm_feature(df, "tbp_lv_A_diff", ["patient_id", "tbp_lv_location"])
    numerical_features += [feature_name]
#     df, feature_name = boosting_norm_feature(df, "tbp_lv_A_diff", ["patient_id", "tbp_lv_location"])
#     numerical_features += [feature_name]

    df["tbp_lv_B_diff"] =  df["tbp_lv_Bext"] - df["tbp_lv_B"]
    df, feature_name = boosting_norm_feature(df, "tbp_lv_B_diff", ["patient_id", "tbp_lv_location"])
    numerical_features += [feature_name]
    
    df["num_images"] = df["patient_id"].map(df.groupby("patient_id")["isic_id"].count())
    numerical_features += ["num_images"]
    return df, numerical_features

# %%
INPUT_PATH = Path("/kaggle/input/isic-2024-challenge/")
MODELS_OUTPUT_PATH = Path(f"{cfg.models_output_dir}")
MODELS_OUTPUT_PATH.mkdir(exist_ok=True)

train_metadata = pd.read_csv(INPUT_PATH / "train-metadata.csv", low_memory=False, na_values=["NA"])
test_metadata = pd.read_csv(INPUT_PATH / "test-metadata.csv", low_memory=False, na_values=["NA"])

folds_df = pd.read_csv("/kaggle/input/isic-scd-folds/folds.csv")
train_metadata = train_metadata.merge(folds_df[[id_column, group_column, cfg.fold_column]], on=[id_column, group_column], how="left")
print(f"Train data size: {train_metadata.shape}")
print(f"Test data size: {test_metadata.shape}")

train_metadata, numerical_features = boosting_feature_engineering(train_metadata)
test_metadata, _ = boosting_feature_engineering(test_metadata)
# Out:
# Train data size: (401059, 56)
# Test data size: (3, 44)

# %%
# cnn_model_names = ["efficientnet_b0", "efficientnet_b1", "efficientnet_b0", "efficientnet_b1", "efficientnet_b2"]
# cnn_versions = ["v1", "v1", "v1", "v2", "v1"]
# cnn_modes = ["trainmulti", "trainmulti", "trainbinary", "trainbinary", "trainbinary"]
# cnn_paths = [f"/kaggle/input/isic-scd-{model_name.replace('_', '-')}-{version}-{mode}" for model_name, version, mode in zip(cnn_model_names, cnn_versions, cnn_modes)]

# all_cnn_oof_columns = []
# for idx, path in enumerate(cnn_paths):
#     model_name = cnn_model_names[idx]
#     version = cnn_versions[idx]
#     mode = cnn_modes[idx]
#     cnn_oof_train_preds_model_df = pd.read_csv(f"{path}/oof_train_preds_{model_name}_{version}.csv")
#     cnn_oof_columns = [col for col in cnn_oof_train_preds_model_df if col.startswith("oof_")]
#     cnn_oof_new_columns = [f"{col}_{mode}" for col in cnn_oof_columns]
#     columns_mapper = dict(zip(cnn_oof_columns, cnn_oof_new_columns))
#     cnn_oof_train_preds_model_df = cnn_oof_train_preds_model_df.rename(columns=columns_mapper)
#     all_cnn_oof_columns += cnn_oof_new_columns
#     if idx == 0:
#         cnn_oof_train_preds_df = cnn_oof_train_preds_model_df[[id_column] + cnn_oof_new_columns].copy()
#     else:
#         cnn_oof_train_preds_df = cnn_oof_train_preds_df.merge(cnn_oof_train_preds_model_df[[id_column] + cnn_oof_new_columns], on=id_column, how="left")
#         assert cnn_oof_train_preds_df.shape[0] == cnn_oof_train_preds_model_df.shape[0]
# train_metadata = train_metadata.merge(cnn_oof_train_preds_df, on=id_column, how="left")
# numerical_features += all_cnn_oof_columns
# cnn_oof_train_preds_df.head()

# %%
mixed_encoded_preprocessor = ColumnTransformer(
    [
        ("numerical", "passthrough", numerical_features),
        (
            "ord_categorical",
            OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-2, encoded_missing_value=-1, dtype=int),
            ord_categorical_features,
        ),
        (
            "ohe_categorical",
            OneHotEncoder(sparse_output=False, dtype=np.int32, handle_unknown="ignore"),
            ohe_categorical_features
        )
    ],
    verbose_feature_names_out=False,

)
mixed_encoded_preprocessor.set_output(transform="pandas")

with open(f"{cfg.model_name}_encoder.joblib", "wb") as f:
    joblib.dump(mixed_encoded_preprocessor, f)

# %%
train_ids = train_metadata[id_column]
groups = train_metadata[group_column]
folds = train_metadata[cfg.fold_column]

enc = mixed_encoded_preprocessor.fit(train_metadata)
X_train = enc.transform(train_metadata)
y_train = np.log1p(train_metadata[target_column])

categorical_features = ord_categorical_features[:]
for ohe_col in ohe_categorical_features:
    categorical_features += [col for col in X_train.columns if col.startswith(ohe_col)]

print(f"Total number of columns: {len(X_train.columns)}")
X_train.head()
# Out:
# Total number of columns: 89
#    age_approx  clin_size_long_diam_mm   tbp_lv_A  tbp_lv_Aext   tbp_lv_B  \
# 0        60.0                    3.04  20.244422    16.261975  26.922447
# 1        60.0                    1.10  31.712570    25.364740  26.331000
# 2        60.0                    3.40  22.575830    17.128170  37.970460
# 3        65.0                    3.22  14.242329    12.164757  21.448144
# 4        55.0                    2.73  24.725520    20.057470  26.464900
#
#    tbp_lv_Bext   tbp_lv_C  tbp_lv_Cext   tbp_lv_H  tbp_lv_Hext   tbp_lv_L  \
# 0    23.954773  33.684638    28.953117  53.058545    55.828924  54.367448
# 1    24.549290  41.219030    35.299260  39.702910    44.064040  48.861520
# 2    33.485410  44.174920    37.611800  59.265850    62.909730  53.961180
# 3    21.121356  25.746200    24.374023  56.414429    60.060388  18.649518
# 4    25.710460  36.217980    32.608740  46.946070    52.041180  46.276310
#
#    tbp_lv_Lext  tbp_lv_areaMM2  tbp_lv_area_perim_ratio  \
# 0    62.025701        3.152561                27.476170
# 1    55.362360        0.919497                12.235290
# 2    61.670520        3.265153                24.184620
# 3    23.314841        6.079940                14.889242
# 4    54.855740        2.101708                19.902560
#
#    tbp_lv_color_std_mean  tbp_lv_deltaA  tbp_lv_deltaB  tbp_lv_deltaL  \
# 0                0.00000       3.982447       2.967674      -7.658253
# 1                0.00000       6.347830       1.781713      -6.500838
# 2                0.00000       5.447655       4.485044      -7.709336
# 3                0.51452       2.077572       0.326788      -4.665323
# 4                0.00000       4.668053       0.754434      -8.579431
#
#    tbp_lv_deltaLB  tbp_lv_deltaLBnorm  tbp_lv_eccentricity  \
# 0        8.360566            5.784302             0.901302
# 1        6.839008            4.987244             0.639885
# 2        9.092376            6.290359             0.932147
# 3        4.783413            6.400196             0.654458
# 4        9.148495            6.531302             0.946448
#
#    tbp_lv_minorAxisMM  tbp_lv_nevi_confidence  tbp_lv_norm_border  \
# 0            1.543016            2.628592e-03            7.091360
# 1            0.821918            1.334303e-07            2.116402
# 2            1.194905            2.959177e-04            4.798335
# 3            2.481328            2.198945e+01            1.975874
# 4            0.929916            1.378832e-03            3.658854
#
#    tbp_lv_norm_color  tbp_lv_perimeterMM  tbp_lv_radial_color_std_max  \
# 0           0.000000            9.307003                      0.00000
# 1           0.000000            3.354148                      0.00000
# 2           0.000000            8.886309                      0.00000
# 3           1.771705            9.514499                      0.66469
# 4           0.000000            6.467562                      0.00000
#
#    tbp_lv_stdL  tbp_lv_stdLExt  tbp_lv_symm_2axis  tbp_lv_symm_2axis_angle  \
# 0     2.036195        2.637780           0.590476                       85
# 1     0.853227        3.912844           0.285714                       55
# 2     1.743651        1.950777           0.361905                      105
# 3     1.258541        1.573733           0.209581                      130
# 4     2.085409        2.480509           0.313433                       20
#
#      tbp_lv_x     tbp_lv_y    tbp_lv_z  age_approx_patient_norm  \
# 0 -182.703552   613.493652  -42.427948                 0.000000
# 1   -0.078308  1575.687000   57.174500                 0.000000
# 2  123.649700  1472.010000  232.908900                 0.000000
# 3 -141.024780  1442.185791   58.359802                 0.000000
# 4  -72.315640  1488.720000   21.428960                 0.067495
#
#    clin_size_long_diam_mm_patient_norm  tbp_lv_A_patient_norm  \
# 0                            -0.463758              -0.105245
# 1                            -1.843134               2.572084
# 2                            -0.153907               0.384721
# 3                            -0.296650              -1.093851
# 4                            -0.684599               1.338774
#
#    tbp_lv_Aext_patient_norm  tbp_lv_B_patient_norm  tbp_lv_Bext_patient_norm  \
# 0                 -0.259588              -0.133360                 -1.058597
# 1                  2.520963               0.222639                  0.508790
# 2                  0.206091               1.686855                  1.552746
# 3                 -0.610289              -1.294002                 -1.511054
# 4                  2.035555               0.148850                  0.298206
#
#    tbp_lv_C_patient_norm  tbp_lv_Cext_patient_norm  tbp_lv_H_patient_norm  \
# 0              -0.166866                 -0.998143              -0.007955
# 1               1.882886                  2.021284              -1.484982
# 2               1.426283                  1.226333               0.921925
# 3              -1.403442                 -1.404220               0.063702
# 4               0.646226                  0.938942              -0.997008
#
#    tbp_lv_Hext_patient_norm  tbp_lv_L_patient_norm  tbp_lv_Lext_patient_norm  \
# 0                 -0.502041               0.797304                  0.550674
# 1                 -1.705589              -1.136750                 -1.406830
# 2                  0.782591               1.207406                  1.173266
# 3                 -0.806844              -2.039950                 -2.154080
# 4                 -1.555847              -0.345077                 -0.550733
#
#    tbp_lv_areaMM2_patient_norm  tbp_lv_area_perim_ratio_patient_norm  \
# 0                    -0.676508                              1.741324
# 1                    -1.137390                             -1.491182
# 2                    -0.514282                              0.525603
# 3                    -0.088794                             -0.806964
# 4                    -0.761842                              0.770101
#
#    tbp_lv_color_std_mean_patient_norm  tbp_lv_deltaA_patient_norm  \
# 0                           -1.390228                    0.221302
# 1                           -1.331239                    0.793910
# 2                           -1.288618                    0.348912
# 3                           -0.734542                   -0.974540
# 4                           -2.135433                   -0.292591
#
#    tbp_lv_deltaB_patient_norm  tbp_lv_deltaL_patient_norm  \
# 0                    1.055810                    0.505632
# 1                   -0.265554                    0.949918
# 2                    0.934931                   -0.437112
# 3                   -0.158758                    1.281338
# 4                   -0.190317                    0.628443
#
#    tbp_lv_deltaLB_patient_norm  tbp_lv_deltaLBnorm_patient_norm  \
# 0                    -0.397698                        -0.527611
# 1                    -1.135598                        -0.882686
# 2                     0.673767                         0.046699
# 3                    -1.366645                        -0.715023
# 4                    -0.590471                        -0.669218
#
#    tbp_lv_eccentricity_patient_norm  tbp_lv_minorAxisMM_patient_norm  \
# 0                          1.128511                        -0.866238
# 1                         -0.924779                        -1.549833
# 2                          1.120625                        -1.073067
# 3                         -0.732262                         0.273470
# 4                          1.798689                        -1.587506
#
#    tbp_lv_nevi_confidence_patient_norm  tbp_lv_norm_border_patient_norm  \
# 0                            -0.516717                         2.172028
# 1                            -0.670061                        -1.016883
# 2                            -0.517487                         0.274178
# 3                            -0.582355                        -0.892887
# 4                            -1.451434                         0.857776
#
#    tbp_lv_norm_color_patient_norm  tbp_lv_perimeterMM_patient_norm  \
# 0                       -1.408906                        -0.394340
# 1                       -1.360397                        -1.656077
# 2                       -1.287268                        -0.419559
# 3                       -0.657291                        -0.265545
# 4                       -2.167810                        -0.945208
#
#    tbp_lv_radial_color_std_max_patient_norm  tbp_lv_stdL_patient_norm  \
# 0                                 -1.340771                 -0.254889
# 1                                 -1.334786                 -1.065580
# 2                                 -1.183910                 -0.048315
# 3                                 -0.497979                 -1.012123
# 4                                 -2.051605                 -0.682808
#
#    tbp_lv_stdLExt_patient_norm  tbp_lv_symm_2axis_patient_norm  \
# 0                     0.172754                        2.161314
# 1                     2.365189                       -0.401978
# 2                    -0.528480                       -0.078132
# 3                    -1.062514                       -0.824696
# 4                     0.404821                        0.741507
#
#    tbp_lv_symm_2axis_angle_patient_norm  tbp_lv_x_patient_norm  \
# 0                             -0.002674              -0.718374
# 1                             -0.667045               0.019220
# 2                              0.313533               0.515830
# 3                              0.808777              -0.773767
# 4                             -1.123920              -0.491157
#
#    tbp_lv_y_patient_norm  tbp_lv_z_patient_norm  tbp_lv_H_diff  \
# 0              -1.187167              -0.891780      -2.770379
# 1               1.349542               0.545008      -4.361130
# 2               0.779559               1.535307      -3.643880
# 3               1.167689               0.025594      -3.645959
# 4               0.964000              -0.606061      -5.095110
#
#    tbp_lv_A_diff_patient_norm  tbp_lv_B_diff_patient_norm  num_images  sex  \
# 0                   -0.182228                   -0.937821         510    1
# 1                   -0.956602                   -0.391149         113    1
# 2                   -0.846660                   -0.871085        1859    1
# 3                    1.047157                    0.125727         541    1
# 4                    0.432704                    0.757054         440    1
#
#    tbp_lv_location  tbp_tile_type  tbp_lv_location_simple  \
# 0               12              1                       4
# 1                0              1                       0
# 2               16              0                       5
# 3               19              0                       6
# 4               19              1                       6
#
#    anatom_site_general_anterior torso  anatom_site_general_head/neck  \
# 0                                   0                              0
# 1                                   0                              1
# 2                                   0                              0
# 3                                   1                              0
# 4                                   1                              0
#
#    anatom_site_general_lower extremity  \
# 0                                    1
# 1                                    0
# 2                                    0
# 3                                    0
# 4                                    0
#
#    anatom_site_general_missing_anatom_site_general  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
#
#    anatom_site_general_posterior torso  anatom_site_general_upper extremity  \
# 0                                    0                                    0
# 1                                    0                                    0
# 2                                    1                                    0
# 3                                    0                                    0
# 4                                    0                                    0
#
#    attribution_ACEMIDMIA  attribution_DoD_HCB  attribution_DoD_UA  \
# 0                      0                    0                   0
# 1                      0                    0                   0
# 2                      0                    0                   0
# 3                      1                    0                   0
# 4                      0                    0                   0
#
#    attribution_FI_TUQ-DRC  attribution_MSKCC  attribution_UHB  \
# 0                       0                  1                0
# 1                       0                  1                0
# 2                       0                  1                0
# 3                       0                  0                0
# 4                       0                  1                0
#
#    attribution_ViDIR
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
num_rounds = 3000
es_rounds = 250
log_rounds = 50

params = {
    "enable_categorical": True,
    "tree_method":        "hist",
    "random_state":       cfg.seed,
    "learning_rate":      0.08501257473292347, 
    "lambda":             8.879624125465703, 
    "alpha":              0.6779926606782505, 
    "max_depth":          6, 
    "subsample":          0.6012681388711075, 
    "colsample_bytree":   0.8437772277074493, 
    "colsample_bylevel":  0.5476090898823716, 
    "colsample_bynode":   0.9928601203635129, 
    "scale_pos_weight":   3.29440313334688,
    "verbosity":          0,
    "disable_default_eval_metric": True
}

# %%
best_num_rounds = {}
val_rmse_scores = {}
all_folds = np.unique(folds)
oof_predictions = np.zeros(X_train.shape[0])
for fold in all_folds:
    print(f"Running fold: {fold}")
    dev_index = folds[folds != fold].index
    val_index = folds[folds == fold].index
    
    X_dev = X_train.loc[dev_index, :]
    y_dev = y_train[dev_index]
    
#     rus = RandomUnderSampler(sampling_strategy=cfg.sampling_ratio, random_state=cfg.seed)
#     X_dev, y_dev = rus.fit_resample(X_dev, y_dev) 
    
    X_val = X_train.loc[val_index, :]
    y_val = y_train[val_index]
    
    model = xgb.XGBRegressor(n_estimators=num_rounds, **params, 
                              eval_metric="rmse", 
                              callbacks=[EarlyStopping(rounds=es_rounds, 
                                                       maximize=False, 
                                                       save_best=True)
                                        ]
                             )
    model.fit(X_dev, y_dev,
              eval_set=[(X_val, y_val)],
              verbose=log_rounds
             )
    best_num_rounds[f"fold_{fold}"] = model.best_iteration
    print(f"Best score: {model.best_score}")
    
    val_preds = model.predict(X_val)
    oof_predictions[val_index] = val_preds
    
    val_rmse_scores[f"fold_{fold}"] = mean_squared_error(y_val, val_preds) ** 0.5
    print("\n")
    
    with open(MODELS_OUTPUT_PATH / f"{cfg.model_name}_fold_{fold}.txt", "wb") as f:
        joblib.dump(model, f)

print("Val RMSE scores:")
pprint(val_rmse_scores)

oof_train_preds_df = pd.DataFrame({
    id_column: train_ids,
    group_column: groups,
    "fold": folds,
    target_column: y_train,
    f"oof_{cfg.model_name}": np.expm1(oof_predictions)
})
oof_train_preds_df.to_csv(f"oof_train_preds_{cfg.model_name}.csv", index=False)

cv_rmse_oof = mean_squared_error(oof_train_preds_df[target_column], oof_train_preds_df[f"oof_{cfg.model_name}"]) ** 0.5
cv_rmse_avg = np.mean(list(val_rmse_scores.values()))
cv_rmse_std = np.std(list(val_rmse_scores.values()))

print(f"CV RMSE OOF: {cv_rmse_oof}")
print(f"CV RMSE AVG: {cv_rmse_avg}")
print(f"CV RMSE STD: {cv_rmse_std}")
print(f"CV RMSE RANGE: ({cv_rmse_avg - cv_rmse_std}, {cv_rmse_avg + cv_rmse_std})")
print(X_train.columns)
# Out:
# Running fold: 1
# [0]	validation_0-rmse:0.18999
# [50]	validation_0-rmse:0.14355
# [100]	validation_0-rmse:0.13965
# [150]	validation_0-rmse:0.13827
# [200]	validation_0-rmse:0.13750
# [250]	validation_0-rmse:0.13667
# [300]	validation_0-rmse:0.13619
# [350]	validation_0-rmse:0.13583
# [400]	validation_0-rmse:0.13560
# [450]	validation_0-rmse:0.13543
# [500]	validation_0-rmse:0.13497
# [550]	validation_0-rmse:0.13488
# [600]	validation_0-rmse:0.13475
# [650]	validation_0-rmse:0.13473
# [700]	validation_0-rmse:0.13468
# [750]	validation_0-rmse:0.13451
# [800]	validation_0-rmse:0.13443
# [850]	validation_0-rmse:0.13430
# [900]	validation_0-rmse:0.13424
# [950]	validation_0-rmse:0.13415
# [1000]	validation_0-rmse:0.13412
# [1050]	validation_0-rmse:0.13406
# [1100]	validation_0-rmse:0.13399
# [1150]	validation_0-rmse:0.13401
# [1200]	validation_0-rmse:0.13394
# [1250]	validation_0-rmse:0.13389
# [1300]	validation_0-rmse:0.13387
# [1350]	validation_0-rmse:0.13383
# [1400]	validation_0-rmse:0.13375
# [1450]	validation_0-rmse:0.13373
# [1500]	validation_0-rmse:0.13377
# [1550]	validation_0-rmse:0.13374
# [1600]	validation_0-rmse:0.13375
# [1650]	validation_0-rmse:0.13374
# [1700]	validation_0-rmse:0.13373
# [1750]	validation_0-rmse:0.13369
# [1800]	validation_0-rmse:0.13373
# [1850]	validation_0-rmse:0.13374
# [1900]	validation_0-rmse:0.13373
# [1950]	validation_0-rmse:0.13377
# [1995]	validation_0-rmse:0.13375
# Best score: 0.13367987075521254
#
#
# Running fold: 2
# [0]	validation_0-rmse:0.19245
# [50]	validation_0-rmse:0.13863
# [100]	validation_0-rmse:0.13448
# [150]	validation_0-rmse:0.13286
# [200]	validation_0-rmse:0.13199
# [250]	validation_0-rmse:0.13133
# [300]	validation_0-rmse:0.13085
# [350]	validation_0-rmse:0.13037
# [400]	validation_0-rmse:0.13013
# [450]	validation_0-rmse:0.13005
# [500]	validation_0-rmse:0.12986
# [550]	validation_0-rmse:0.12987
# [600]	validation_0-rmse:0.12969
# [650]	validation_0-rmse:0.12966
# [700]	validation_0-rmse:0.12951
# [750]	validation_0-rmse:0.12944
# [800]	validation_0-rmse:0.12944
# [850]	validation_0-rmse:0.12941
# [900]	validation_0-rmse:0.12927
# [950]	validation_0-rmse:0.12929
# [1000]	validation_0-rmse:0.12923
# [1050]	validation_0-rmse:0.12914
# [1100]	validation_0-rmse:0.12911
# [1150]	validation_0-rmse:0.12905
# [1200]	validation_0-rmse:0.12900
# [1250]	validation_0-rmse:0.12905
# [1300]	validation_0-rmse:0.12909
# [1350]	validation_0-rmse:0.12909
# [1400]	validation_0-rmse:0.12909
# [1437]	validation_0-rmse:0.12906
# Best score: 0.12899237028665395
#
#
# Running fold: 3
# [0]	validation_0-rmse:0.17905
# [50]	validation_0-rmse:0.13471
# [100]	validation_0-rmse:0.13035
# [150]	validation_0-rmse:0.12869
# [200]	validation_0-rmse:0.12772
# [250]	validation_0-rmse:0.12692
# [300]	validation_0-rmse:0.12655
# [350]	validation_0-rmse:0.12650
# [400]	validation_0-rmse:0.12624
# [450]	validation_0-rmse:0.12604
# [500]	validation_0-rmse:0.12591
# [550]	validation_0-rmse:0.12581
# [600]	validation_0-rmse:0.12575
# [650]	validation_0-rmse:0.12570
# [700]	validation_0-rmse:0.12559
# [750]	validation_0-rmse:0.12554
# [800]	validation_0-rmse:0.12535
# [850]	validation_0-rmse:0.12528
# [900]	validation_0-rmse:0.12519
# [950]	validation_0-rmse:0.12518
# [1000]	validation_0-rmse:0.12514
# [1050]	validation_0-rmse:0.12511
# [1100]	validation_0-rmse:0.12512
# [1150]	validation_0-rmse:0.12511
# [1200]	validation_0-rmse:0.12512
# [1250]	validation_0-rmse:0.12506
# [1300]	validation_0-rmse:0.12504
# [1350]	validation_0-rmse:0.12501
# [1400]	validation_0-rmse:0.12500
# [1450]	validation_0-rmse:0.12497
# [1500]	validation_0-rmse:0.12493
# [1550]	validation_0-rmse:0.12493
# [1600]	validation_0-rmse:0.12496
# [1650]	validation_0-rmse:0.12494
# [1700]	validation_0-rmse:0.12496
# [1750]	validation_0-rmse:0.12497
# [1797]	validation_0-rmse:0.12497
# Best score: 0.12491611002199433
#
#
# Running fold: 4
# [0]	validation_0-rmse:0.17636
# [50]	validation_0-rmse:0.12948
# [100]	validation_0-rmse:0.12593
# [150]	validation_0-rmse:0.12463
# [200]	validation_0-rmse:0.12388
# [250]	validation_0-rmse:0.12333
# [300]	validation_0-rmse:0.12312
# [350]	validation_0-rmse:0.12278
# [400]	validation_0-rmse:0.12270
# [450]	validation_0-rmse:0.12237
# [500]	validation_0-rmse:0.12237
# [550]	validation_0-rmse:0.12228
# [600]	validation_0-rmse:0.12222
# [650]	validation_0-rmse:0.12221
# [700]	validation_0-rmse:0.12226
# [750]	validation_0-rmse:0.12231
# [800]	validation_0-rmse:0.12229
# [850]	validation_0-rmse:0.12220
# [859]	validation_0-rmse:0.12222
# Best score: 0.12217691666817865
#
#
# Running fold: 5
# [0]	validation_0-rmse:0.15886
# [50]	validation_0-rmse:0.12567
# [100]	validation_0-rmse:0.12266
# [150]	validation_0-rmse:0.12173
# [200]	validation_0-rmse:0.12147
# [250]	validation_0-rmse:0.12099
# [300]	validation_0-rmse:0.12082
# [350]	validation_0-rmse:0.12085
# [400]	validation_0-rmse:0.12076
# [450]	validation_0-rmse:0.12079
# [500]	validation_0-rmse:0.12075
# [550]	validation_0-rmse:0.12075
# [600]	validation_0-rmse:0.12070
# [650]	validation_0-rmse:0.12055
# [700]	validation_0-rmse:0.12041
# [750]	validation_0-rmse:0.12037
# [800]	validation_0-rmse:0.12045
# [850]	validation_0-rmse:0.12041
# [900]	validation_0-rmse:0.12036
# [950]	validation_0-rmse:0.12033
# [1000]	validation_0-rmse:0.12037
# [1050]	validation_0-rmse:0.12033
# [1100]	validation_0-rmse:0.12034
# [1150]	validation_0-rmse:0.12036
# [1196]	validation_0-rmse:0.12037
# Best score: 0.12030735189856952
#
#
# Val RMSE scores:
# {'fold_1': 0.1336798706412866,
#  'fold_2': 0.12899237016442522,
#  'fold_3': 0.12491611031729521,
#  'fold_4': 0.12217691664695246,
#  'fold_5': 0.1203073520475003}
# CV RMSE OOF: 92.48326266144535
# CV RMSE AVG: 0.12601452396349197
# CV RMSE STD: 0.004819349778133619
# CV RMSE RANGE: (0.12119517418535836, 0.13083387374162558)
# Index(['age_approx', 'clin_size_long_diam_mm', 'tbp_lv_A', 'tbp_lv_Aext',
#        'tbp_lv_B', 'tbp_lv_Bext', 'tbp_lv_C', 'tbp_lv_Cext', 'tbp_lv_H',
#        'tbp_lv_Hext', 'tbp_lv_L', 'tbp_lv_Lext', 'tbp_lv_areaMM2',
#        'tbp_lv_area_perim_ratio', 'tbp_lv_color_std_mean', 'tbp_lv_deltaA',
#        'tbp_lv_deltaB', 'tbp_lv_deltaL', 'tbp_lv_deltaLB',
#        'tbp_lv_deltaLBnorm', 'tbp_lv_eccentricity', 'tbp_lv_minorAxisMM',
#        'tbp_lv_nevi_confidence', 'tbp_lv_norm_border', 'tbp_lv_norm_color',
#        'tbp_lv_perimeterMM', 'tbp_lv_radial_color_std_max', 'tbp_lv_stdL',
#        'tbp_lv_stdLExt', 'tbp_lv_symm_2axis', 'tbp_lv_symm_2axis_angle',
#        'tbp_lv_x', 'tbp_lv_y', 'tbp_lv_z', 'age_approx_patient_norm',
#        'clin_size_long_diam_mm_patient_norm', 'tbp_lv_A_patient_norm',
#        'tbp_lv_Aext_patient_norm', 'tbp_lv_B_patient_norm',
#        'tbp_lv_Bext_patient_norm', 'tbp_lv_C_patient_norm',
#        'tbp_lv_Cext_patient_norm', 'tbp_lv_H_patient_norm',
#        'tbp_lv_Hext_patient_norm', 'tbp_lv_L_patient_norm',
#        'tbp_lv_Lext_patient_norm', 'tbp_lv_areaMM2_patient_norm',
#        'tbp_lv_area_perim_ratio_patient_norm',
#        'tbp_lv_color_std_mean_patient_norm', 'tbp_lv_deltaA_patient_norm',
#        'tbp_lv_deltaB_patient_norm', 'tbp_lv_deltaL_patient_norm',
#        'tbp_lv_deltaLB_patient_norm', 'tbp_lv_deltaLBnorm_patient_norm',
#        'tbp_lv_eccentricity_patient_norm', 'tbp_lv_minorAxisMM_patient_norm',
#        'tbp_lv_nevi_confidence_patient_norm',
#        'tbp_lv_norm_border_patient_norm', 'tbp_lv_norm_color_patient_norm',
#        'tbp_lv_perimeterMM_patient_norm',
#        'tbp_lv_radial_color_std_max_patient_norm', 'tbp_lv_stdL_patient_norm',
#        'tbp_lv_stdLExt_patient_norm', 'tbp_lv_symm_2axis_patient_norm',
#        'tbp_lv_symm_2axis_angle_patient_norm', 'tbp_lv_x_patient_norm',
#        'tbp_lv_y_patient_norm', 'tbp_lv_z_patient_norm', 'tbp_lv_H_diff',
#        'tbp_lv_A_diff_patient_norm', 'tbp_lv_B_diff_patient_norm',
#        'num_images', 'sex', 'tbp_lv_location', 'tbp_tile_type',
#        'tbp_lv_location_simple', 'anatom_site_general_anterior torso',
#        'anatom_site_general_head/neck', 'anatom_site_general_lower extremity',
#        'anatom_site_general_missing_anatom_site_general',
#        'anatom_site_general_posterior torso',
#        'anatom_site_general_upper extremity', 'attribution_ACEMIDMIA',
#        'attribution_DoD_HCB', 'attribution_DoD_UA', 'attribution_FI_TUQ-DRC',
#        'attribution_MSKCC', 'attribution_UHB', 'attribution_ViDIR'],
#       dtype='object')

# %%
oof_train_preds_df.head()
# Out:
#         isic_id  patient_id  fold  tbp_lv_dnn_lesion_confidence  oof_xgb_v2
# 0  ISIC_0015670  IP_1235828     4                      4.590232   94.342399
# 1  ISIC_0015845  IP_8170065     1                      1.421047   21.509917
# 2  ISIC_0015864  IP_6724798     5                      4.613178   98.505276
# 3  ISIC_0015902  IP_4111386     2                      4.615021  101.592905
# 4  ISIC_0024200  IP_8313778     1                      4.268893   81.657752

# %%
feature_importances = 0
for fold in all_folds:
    model_filepath = MODELS_OUTPUT_PATH / f"{cfg.model_name}_fold_{fold}.txt"
    with open(model_filepath, "rb") as f:
        model = joblib.load(f)
    if fold == 1:
        feature_names = model.feature_names_in_
    feature_importances += model.feature_importances_
feature_importances = feature_importances.astype(np.float32)
feature_importances /= len(all_folds)

# %%
imp = pd.DataFrame.from_dict(dict(zip(feature_names, feature_importances)), 
                             orient="index", columns=["imp"]).sort_values("imp", ascending=True)
imp.plot(kind="barh", figsize=(10, 30))
plt.show()

# %%
metadata = {
    "config": cfg.__dict__,
    "params": params,
    "num_rounds": num_rounds,
    "es_rounds": es_rounds,
    "best_num_rounds": best_num_rounds,
    "val_rmse_scores": val_rmse_scores,
    "cv_rmse_oof": cv_rmse_oof,
    "cv_rmse_avg": cv_rmse_avg,
    "cv_rmse_std": cv_rmse_std,
}

with open(f"{cfg.model_name}_run_metadata.json", "w") as f:
    json.dump(metadata, f)

# %%
metadata
# Out:
# {'config': {'_temp': False,
#   '_key': None,
#   '_parent': None,
#   'seed': 2022,
#   'models_output_dir': 'models',
#   'model_name': 'xgb_v2',
#   'fold_column': 'gkf_fold',
#   'sampling_ratio': 0.01},
#  'params': {'enable_categorical': True,
#   'tree_method': 'hist',
#   'random_state': 2022,
#   'learning_rate': 0.08501257473292347,
#   'lambda': 8.879624125465703,
#   'alpha': 0.6779926606782505,
#   'max_depth': 6,
#   'subsample': 0.6012681388711075,
#   'colsample_bytree': 0.8437772277074493,
#   'colsample_bylevel': 0.5476090898823716,
#   'colsample_bynode': 0.9928601203635129,
#   'scale_pos_weight': 3.29440313334688,
#   'verbosity': 0,
#   'disable_default_eval_metric': True},
#  'num_rounds': 3000,
#  'es_rounds': 250,
#  'best_num_rounds': {'fold_1': 1745,
#   'fold_2': 1188,
#   'fold_3': 1547,
#   'fold_4': 610,
#   'fold_5': 946},
#  'val_rmse_scores': {'fold_1': 0.1336798706412866,
#   'fold_2': 0.12899237016442522,
#   'fold_3': 0.12491611031729521,
#   'fold_4': 0.12217691664695246,
#   'fold_5': 0.1203073520475003},
#  'cv_rmse_oof': 92.48326266144535,
#  'cv_rmse_avg': 0.12601452396349197,
#  'cv_rmse_std': 0.004819349778133619}
